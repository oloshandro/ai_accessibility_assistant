# %%
def add_text_column_to_df(df):
    """Add a 'text' column to the DataFrame with accessibility info combined."""
    
    def row_to_text(row):
        return f"""Назва: {row['Назва']}
            Адреса: {row['Адреса']}
            Тип закладу: {row['Тип закладу']}
            Доступність:
            - Пандус: {"є" if row['Пандус'] == 1 else "відсутній"}
            - Табличка з шрифтом Брайля: {"є" if row['Табличка з шрифтом Брайля'] == 1 else "відсутня"}
            - Тактильна плитка: {"є" if row['Тактильна плитка'] == 1 else "відсутня"}
            - Кнопка виклику персоналу: {"є" if row['Кнопка виклику персоналу'] == 1 else "відсутня"}
            - Паркомісця для людей з інвалідністю: {"є" if row['Паркомісця для людей з інвалідністю'] == 1 else "відсутні"}
            - Широкі двері для людей з інвалідністю: {"є" if row['Широкі двері для людей з інвалідністю'] == 1 else "відсутні"}"""

    df["text"] = df.apply(row_to_text, axis=1)
    return df

# %%
import pandas as pd
df = pd.read_csv("../knowledge/accessibility_chernihiv.csv", encoding="utf-8")
df = add_text_column_to_df(df)

# %%
# Save new version with the 'text' column
df.to_csv("../knowledge/accessibility_data_with_text.csv", index=False)

# %%
df.head(5)
# Out:
#                  Назва                 Адреса          Тип закладу  Пандус  \
# 0   "Бажаємо здоров'я"  Вул. Преображенська 2               Аптека       1
# 1                ACBIO  Вул. Преображенська 2                 Банк       1
# 2  Філармонійний центр         Просп. Миру 15  Філармонійний центр       1
# 3             ZooBonus         Просп. Миру 17           Зоомагазин       1
# 4         Правекс банк         Просп. Миру 17                 Банк       1
#
#    Табличка з шрифтом Брайля  Тактильна плитка  Кнопка виклику персоналу  \
# 0                          1                 1                         1
# 1                          1                 1                         1
# 2                          0                 0                         1
# 3                          0                 0                         0
# 4                          1                 1                         0
#
#    Паркомісця для людей з інвалідністю  Широкі двері для людей з інвалідністю  \
# 0                                    0                                      1
# 1                                    0                                      1
# 2                                    0                                      1
# 3                                    0                                      1
# 4                                    0                                      1
#
#    Вбиральні для людей з інвалідністю  \
# 0                                   0
# 1                                   0
# 2                                   0
# 3                                   0
# 4                                   0
#
#                                                 text
# 0  Назва: "Бажаємо здоров'я"\n            Адреса:...
# 1  Назва: ACBIO\n            Адреса: Вул. Преобра...
# 2  Назва: Філармонійний центр\n            Адреса...
# 3  Назва: ZooBonus\n            Адреса: Просп. Ми...
# 4  Назва: Правекс банк\n            Адреса: Просп...

# %%
df["text"]
# Out:
# 0     Назва: "Бажаємо здоров'я"\n            Адреса:...
# 1     Назва: ACBIO\n            Адреса: Вул. Преобра...
# 2     Назва: Філармонійний центр\n            Адреса...
# 3     Назва: ZooBonus\n            Адреса: Просп. Ми...
# 4     Назва: Правекс банк\n            Адреса: Просп...
# 5     Назва: Ощадбанк\n            Адреса: Просп. Ми...
# 6     Назва: Солобіє\n            Адреса: Просп. Мир...
# 7     Назва: Raiffeisen Bank\n            Адреса: Пр...
# 8     Назва: Підземний перехід \n            Адреса:...
# 9     Назва: Аптека "БАМ"\n            Адреса: Просп...
# 10    Назва: Аврора\n            Адреса: Просп. Пере...
# 11    Назва: Аптека оптових цін\n            Адреса:...
# 12    Назва: Соціальна аптека\n            Адреса: В...
# 13    Назва: McDonald’s\n            Адреса: Вул. Кн...
# 14    Назва: Pasta Basta\n            Адреса: Просп....
# 15    Назва: Шарлотка\n            Адреса: Просп. Ми...
# 16    Назва: Марконі\n            Адреса: Просп. Мир...
# 17    Назва: Familia Italiana\n            Адреса: В...
# 18    Назва: Варенична "Балувана Галя"\n            ...
# 19    Назва: Софра\n            Адреса: Просп. Миру ...
# 20    Назва: Громадський транспорт\n            Адре...
# 21    Назва: ТРЦ "Hollywood"\n            Адреса: Пр...
# 22    Назва: Ощадбанк\n            Адреса: Просп. Ле...
# 23    Назва: Sense Bank\n            Адреса: Просп. ...
# 24    Назва: Аврора\n            Адреса: Просп. Левк...
# 25    Назва: Rozetka\n            Адреса: Просп. Лев...
# 26    Назва: CSD LAB\n            Адреса: Просп. Лев...
# 27    Назва: Нова Пошта № 4\n            Адреса: Про...
# 28    Назва: Аптека "Бажаємо здоров'я" \n           ...
# 29    Назва: Аптека "Низьких цін"\n            Адрес...
# 30    Назва: Аврора\n            Адреса: Просп. Левк...
# 31    Назва: Da Vinchi\n            Адреса: Просп. Л...
# 32    Назва: Центр ментального здоров'я\n           ...
# 33    Назва: Дніпролаб\n            Адреса: Просп. Л...
# 34    Назва: Сімейна поліклініка\n            Адреса...
# 35    Назва: Аптека "Бажаємо здоров'я" \n           ...
# 36    Назва: Аврора\n            Адреса: Просп. Левк...
# 37    Назва: Defile\n            Адреса: Просп. Левк...
# 38    Назва: ДяДя Чебурек\n            Адреса: Просп...
# 39    Назва: Продукти\n            Адреса: Просп. Ле...
# 40    Назва: ЦНАП\n            Адреса: Просп. Левка ...
# 41    Назва: Майстерня краси "De Fleur"\n           ...
# 42    Назва: АТБ\n            Адреса: Просп. Левка Л...
# 43    Назва: Аптека оптових цін\n            Адреса:...
# 44    Назва: АТБ\n            Адреса: Просп. Левка Л...
# 45    Назва: Аптека "Подорожник"\n            Адреса...
# 46    Назва: Пумб\n            Адреса: Просп. Левка ...
# 47    Назва: Vape king shop\n            Адреса: Про...
# 48    Назва: Перший ломбард\n            Адреса: Про...
# 49    Назва: Аптека "Подорожник"\n            Адреса...
# 50    Назва: Центральна районна лікарня\n           ...
# 51    Назва: Ощадбанк\n            Адреса: Просп. Ле...
# 52    Назва: FILADA\n            Адреса: Вул. Святом...
# 53    Назва: ПриватБанк\n            Адреса: Вул. Бо...
# 54    Назва: Чернігівський обласний художній музей і...
# 55    Назва: Державний архів Чернігівської області\n...
# Name: text, dtype: object
